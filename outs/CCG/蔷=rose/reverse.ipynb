# %%
from PIL import Image, ImageOps

img = Image.open('/home/weiyuxiang/kailai/wordart/preds_cn_crop/蔷=rose/raw_image.jpg').convert("L")

r_img = ImageOps.invert(img)

display(r_img)
# Out:
# <PIL.Image.Image image mode=L size=500x512>
